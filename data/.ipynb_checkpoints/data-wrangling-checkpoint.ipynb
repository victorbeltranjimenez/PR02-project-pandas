# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
df = pd.read_csv('GSAF5.csv', encoding = "Latin1") # == encoding('ISO-8859-1')

# %% [markdown]
# ## Vistra prebia del DF a trabajar

# %%
df.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#     Species        Investigator or Source                        pdf  \
# ...

# %%
df.tail()
# Out:
#      Case Number         Date  Year        Type             Country  \
# 5987     ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5988     ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 5989     ND.0003    1900-1905     0  Unprovoked                 USA
# 5990     ND.0002    1883-1889     0  Unprovoked              PANAMA
# 5991     ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 5987  Western Australia                          Roebuck Bay        Diving
# 5988  Western Australia                                  NaN  Pearl diving
# 5989     North Carolina                       Ocracoke Inlet      Swimming
# 5990                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 5991   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ... Species   \
# 5987                   male    M  ...      NaN
# ...

# %%
df.shape
# Out:
# (5992, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5992 entries, 0 to 5991
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             5992 non-null   object
#  1   Date                    5992 non-null   object
#  2   Year                    5992 non-null   int64
#  3   Type                    5992 non-null   object
#  4   Country                 5949 non-null   object
#  5   Area                    5590 non-null   object
#  6   Location                5496 non-null   object
#  7   Activity                5465 non-null   object
#  8   Name                    5792 non-null   object
#  9   Sex                     5425 non-null   object
#  10  Age                     3311 non-null   object
#  11  Injury                  5965 non-null   object
#  12  Fatal (Y/N)             5973 non-null   object
#  13  Time                    2779 non-null   object
# ...

# %%
df.describe()
# Out:
#               Year  original order
# count  5992.000000     5992.000000
# mean   1925.204606     2997.548899
# std     286.473712     1729.860210
# min       0.000000        2.000000
# 25%    1942.000000     1499.750000
# 50%    1975.000000     2997.500000
# 75%    2003.000000     4495.250000
# max    2016.000000     5993.000000

# %%
df[['Name', 'Sex ']].head(30)
# Out:
#                        Name Sex
# 0                      male    M
# 1            Chucky Luciano    M
# 2                      male    M
# 3           Rory Angiolella    M
# 4                      male    M
# 5    Occupant: Ben Stratton  NaN
# 6                      male    M
# 7                    female    F
# 8              David Jewell    M
# 9            Rylie Williams    F
# 10            Fraser Penman    M
# 11             Austin Moore    M
# 12         Tyler McQuillen     M
# 13            Sam Cumiskey     M
# 14                     male    M
# 15        Laurent Chardard     M
# 16           David Cassetty    M
# 17             Johnny Stoch    M
# 18            Connor Baxter    M
# 19              Nolan Tyler    M
# 20                     male    M
# 21             Justus Franz    M
# 22              Ian Watkins    M
# 23              Warren Sapp    M
# 24  Curran See & Harry Lake    M
# 25                     male    M
# 26        Zebulon Critchlow    M
# ...

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Case Number                  0
# Date                         0
# Year                         0
# Type                         0
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# pdf                          0
# href formula                 1
# href                         3
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %% [markdown]
# ## Limpieza:
#     -Elim. 'Year' por simplificar. Podemos hacer un cut en caso de volver a necesitarlo. Asegurando que corresponde al año correcto sobre la fecha.
#     -Elim. 'Location' al no trabajar por el lugar en concreto. Mantenemos País como forma de agrupación por localización
#     -Elim. 'Name'&'Sex' por su irrelevancia en el primer caso, y por no trabajar sobre datos del 2º
#     -Elim. 'Injury' al no entrar en detalle por la complejidad de las diferentes consecuencias #3596 len(df['Injury'].unique())
#     -Elim. de las columnas Unnamed: 22 y Unnamed: 23 por falta de datos.
#     -Elim. 'Time' y 'Species' por falta de datos
#     -Elim. 'Inv. or Source', 'pdf', 'href formula', 'href','Case Number.1&2, 'original order','Unnamed: 22', 'Unnamed: 23' por no trabajar sobre ellos.

# %%
df = df[['Case Number', 'Date', 'Type', 'Country', 'Area', 'Activity', 'Injury', 'Fatal (Y/N)']]

# %%
df
# Out:
#        Case Number         Date        Type             Country  \
# 0     2016.09.18.c    18-Sep-16  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  Unprovoked           AUSTRALIA
# ...            ...          ...         ...                 ...
# 5987       ND.0005  Before 1903  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905  Unprovoked                 USA
# 5990       ND.0002    1883-1889  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area      Activity  \
# 0               Florida       Surfing
# 1               Florida       Surfing
# 2               Florida       Surfing
# 3              Victoria       Surfing
# ...

# %%
df_spain = df['Country'].str.startswith('SPAIN',  na = False)

# %%
df_spain = df[df_spain]

# %%
df_spain_fatal = df_spain[df_spain['Fatal (Y/N)']=='Y']

# %%
df_spain_fatal
# Out:
#        Case Number                  Date        Type Country  \
# 5143    1912.00.00                  1912  Unprovoked   SPAIN
# 5150  1911.07.31.R  Reported 31-Jul-1911  Unprovoked   SPAIN
# 5196  1908.08.28.R  Reported 28-Aug-1908  Unprovoked   SPAIN
# 5197  1908.07.18.R  Reported 18-Jul-1908     Invalid   SPAIN
# 5683    1864.07.25           25-Jul-1864  Unprovoked   SPAIN
# 5700    1862.07.25           25-Jul-1862  Unprovoked   SPAIN
# 5701    1862.07.14           14-Jul-1862  Unprovoked   SPAIN
# 5702    1862.07.13           13-Jul-1862  Unprovoked   SPAIN
# 5842    1764.00.00                  1764  Unprovoked   SPAIN
#
#                   Area                                  Activity  \
# 5143         Balearics                       Fell into the water
# 5150           Málaga                                    Bathing
# 5196           Galicia  Fell overboard from P&O steamship Arabia
# 5197    Canary Islands                                       NaN
# ...

# %%
df.isnull().sum()
# Out:
# Case Number      0
# Date             0
# Type             0
# Country         43
# Area           402
# Activity       527
# Injury          27
# Fatal (Y/N)     19
# dtype: int64

# %%
df_loc = df['Country'].value_counts()

# %%
df_loc.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Country'>
